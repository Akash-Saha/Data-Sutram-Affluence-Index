# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
dchb_df = pd.read_excel('DCHB_Town_Release_1900.xlsx')

# %%
dchb_df.head()
array(dchb_df.columns)
dchb_df['Households per area'] = dchb_df['Total   Households ']/dchb_df['Area (sq. km.)']
array(dchb_df.columns)
# Out:
# array(['State Code', 'State Name', 'District Code', 'District Name',
#        'Sub District Code', 'Sub District Name', 'Town Code', 'Town Name',
#        'Total   Households ', 'Total Population of Town',
#        'Total Male Population of Town', 'Total Female Population of Town',
#        'Total Scheduled Castes Population of Town',
#        'Total Scheduled Castes  Male Population of Town',
#        'Total Scheduled Castes  Female Population of Town',
#        'Total Scheduled Tribes Population of Town',
#        'Total Scheduled Tribes  Male Population of Town',
#        'Total Scheduled Tribes  Female Population of Town',
#        'Reference Year', 'Class', 'Civic Status of Town',
#        'Name of Taluk/Tahsil/Police Station/Islands etc.',
#        'Name of CD Block', 'Area (sq. km.)',
#        'Number of Households including Houseless Households (2011 Census)',
#        'Scheduled Castes Population (2011 Census)',
#        'Scheduled Tribes Population (2011 Census)',
# ...

# %%
# %matplotlib inline
plt.scatter(dchb_df['Households per area'],dchb_df['Railway Station Road Distance (in kms)'])
plt.xlim(0,5000)
plt.ylim(0,100)
# Out:
# (0, 100)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(asset_df['Total number of households'], asset_df['Computer With Internet'], s=10, c='b', marker="s", label='Computer')
ax1.scatter(asset_df['Total number of households'],y[40:], s=10, c='r', marker="o", label='second')
plt.legend(loc='upper left');
plt.show()
